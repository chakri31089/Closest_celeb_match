# %%
import cv2
import os
import glob
import numpy as np
import time

from Facerec import Facerec

# %%
path = 'data'

# %%
dir_paths=os.listdir(path)

# %%
dir_paths
# Out:
# ['Aamir Khan.jpg',
#  'Abhay_Deol.jpg',
#  'Abhishek_Bachchan.jpg',
#  'Aftab_Shivdasani.jpg',
#  'Aishwarya_Rai.jpg',
#  'Ajay_Devgn.jpg',
#  'Akshaye_Khanna.jpg',
#  'Akshay_Kumar.jpg',
#  'Alia_Bhatt.jpg',
#  'Ameesha_Patel.jpg',
#  'Amitabh_Bachchan.jpg',
#  'Amrita_Rao.jpg',
#  'Amy_Jackson.png',
#  'Anil_Kapoor.jpg',
#  'Anushka_Sharma.png',
#  'Anushka_Shetty.jpg',
#  'Arjun_Kapoor.jpg',
#  'Arjun_Rampal.jpg',
#  'Arshad_Warsi.jpg',
#  'Asin.jpg',
#  'Ayushmann_Khurrana.jpg',
#  'Bhumi_Pednekar.jpg',
#  'Bipasha_Basu.jpg',
#  'Bobby_Deol.jpg',
#  'Deepika_Padukone.jpg',
#  'Disha_Patani.jpg',
#  'Emraan_Hashmi.jpg',
#  'Esha_Gupta.jpg',
#  'Farhan_Akhtar.jpg',
#  'Govinda.jpg',
#  'Hrithik_Roshan.jpg',
#  'Huma_Qureshi.jpg',
#  'Ileana.jpg',
#  'Irrfan_Khan.jpg',
#  'Jacqueline_Fernandez.jpg',
#  'John_Abraham.jpg',
#  'Juhi_Chawla.jpg',
#  'Kajal_Aggarwal.jpg',
#  'Kajol.jpg',
#  'Kangana_Ranaut.jpg',
#  'Kareena_Kapoor.jpg',
#  'Karisma_Kapoor.jpeg',
#  'Kartik_Aaryan.jpg',
# ...

# %%
fr=Facerec()

# %%
    
fr.load_encoding_images(path)
# Out:
# Aamir Khan
# <class 'facenet_pytorch.models.inception_resnet_v1.InceptionResnetV1'>
# Abhay_Deol
# <class 'facenet_pytorch.models.inception_resnet_v1.InceptionResnetV1'>
# Abhishek_Bachchan
# <class 'facenet_pytorch.models.inception_resnet_v1.InceptionResnetV1'>
# Aftab_Shivdasani
# <class 'facenet_pytorch.models.inception_resnet_v1.InceptionResnetV1'>
# Aishwarya_Rai
# <class 'facenet_pytorch.models.inception_resnet_v1.InceptionResnetV1'>
# Ajay_Devgn
# <class 'facenet_pytorch.models.inception_resnet_v1.InceptionResnetV1'>
# Akshaye_Khanna
# <class 'facenet_pytorch.models.inception_resnet_v1.InceptionResnetV1'>
# Akshay_Kumar
# <class 'facenet_pytorch.models.inception_resnet_v1.InceptionResnetV1'>
# Alia_Bhatt
# <class 'facenet_pytorch.models.inception_resnet_v1.InceptionResnetV1'>
# Ameesha_Patel
# <class 'facenet_pytorch.models.inception_resnet_v1.InceptionResnetV1'>
# Amitabh_Bachchan
# <class 'facenet_pytorch.models.inception_resnet_v1.InceptionResnetV1'>
# Amrita_Rao
# ...
